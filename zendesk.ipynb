# %%
user = 'sustentacao@aktienow.com' + '/token'
pwd = '0zlfr6wxlGmbKCBp7nowSROMMGMqsJzw5k7YR5RV'

url = 'https://atendimentogruposbf.zendesk.com/'
endpoint = 'api/v2/tickets/recent'

# %%
import requests


# Do the HTTP get request
response = requests.get(url+endpoint, auth=(user, pwd))

# Check for HTTP codes other than 200
if response.status_code != 200:
    print('Status:', response.status_code, 'Problem with the request. Exiting.')
    exit()

# Decode the JSON response into a dictionary and use the data
data = response.json()

print(data)
# # Example 1: Print the name of the first group in the list
# print( 'First group = ', data['groups'][0]['name'] )

# # Example 2: Print the name of each group in the list
# group_list = data['groups']
# for group in group_list:
#     print(group['name'])
# Out:
# {'tickets': [{'url': 'https://atendimentogruposbf.zendesk.com/api/v2/tickets/5060713.json', 'id': 5060713, 'external_id': None, 'via': {'channel': 'api', 'source': {'from': {}, 'to': {}, 'rel': None}}, 'created_at': '2022-10-26T21:21:29Z', 'updated_at': '2022-10-26T21:21:29Z', 'type': None, 'subject': 'Solicitação de troca devolução - Protocolo Portal', 'raw_subject': 'Solicitação de troca devolução - Protocolo Portal', 'description': 'ID do pedido: 942351075\nMotivo: Tamanho\nEtiqueta de postagem: 2279460515\nDescrição do produto: Camisa Nike Brasil II 2022/23 Torcedor Pro Masculina\nQuantidade: 1\n\nValor: R$349.99\nForma de restituição: Vale-troca\n', 'priority': 'high', 'status': 'pending', 'recipient': None, 'requester_id': 10733665939731, 'submitter_id': 10733665939731, 'assignee_id': None, 'organization_id': None, 'group_id': 6302858935059, 'collaborator_ids': [], 'follower_ids': [], 'email_cc_ids': [], 'forum_topic_id': None, 'problem_id': None, 'has_incidents': False, 'is_public': True, 'due_at': None, 'tags': ['acompanhamento_ti', 'atendido_vale_troca', 'canal_de_entrada_campo_obrigatorio_portal_do_cliente', 'hide_cs_falar_com', 'motivo_de_contato_sac_trocas_e_devolucoes_clonar', 'not_enviada', 'sem_resposta', 'sub_devolucao_de_produto_tamanho', 'sub_trocas_e_devolucoes_sac_devolucao_de_produto_clonar', 'ticket_pai_ou_filho_pai', 'ticket_portal_cliente'], 'custom_fields': [{'id': 1900000134145, 'value': None}, {'id': 1900000135425, 'value': None}, {'id': 1500007590401, 'value': None}, {'id': 1500007431681, 'value': None}, {'id': 1500007498242, 'value': None}, {'id': 1900000134405, 'value': None}, {'id': 1500010102021, 'value': None}, {'id': 1500007431941, 'value': None}, {'id': 1500007498502, 'value': None}, {'id': 1500007497222, 'value': None}, {'id': 1500007432201, 'value': None}, {'id': 1900000134665, 'value': None}, {'id': 1900000219145, 'value': None}, {'id': 1500007430921, 'value': None}, {'id': 1500007498762, 'value': None}, {'id': 1500012142602, 'value': None}, {'id': 1500007497482, 'value': None}, {'id': 1500007432461, 'value': None}, {'id': 1500007502861, 'value': None}, {'id': 1500007506701, 'value': None}, {'id': 1900000133645, 'value': None}, {'id': 1900000134925, 'value': None}, {'id': 1900000209165, 'value': None}, {'id': 1900003759885, 'value': None}, {'id': 1500007431181, 'value': None}, {'id': 1500007497742, 'value': None}, {'id': 1900000133905, 'value': None}, {'id': 1900000135185, 'value': None}, {'id': 1900000219665, 'value': None}, {'id': 1500010029841, 'value': None}, {'id': 1900001161745, 'value': None}, {'id': 1500007431441, 'value': None}, {'id': 1500007498002, 'value': None}, {'id': 1500009501202, 'value': None}, {'id': 6301094183699, 'value': None}, {'id': 6301130556691, 'value': None}, {'id': 6543403126035, 'value': None}, {'id': 9280491622419, 'value': None}, {'id': 9780879889171, 'value': None}, {'id': 6301096088851, 'value': None}, {'id': 6301066991123, 'value': None}, {'id': 6301111555859, 'value': None}, {'id': 7997160691987, 'value': None}, {'id': 6301083048467, 'value': None}, {'id': 6301122960915, 'value': None}, {'id': 6301106315539, 'value': None}, {'id': 7904894984723, 'value': None}, {'id': 6301086130963, 'value': None}, {'id': 9526122914579, 'value': None}, {'id': 6265547006739, 'value': None}, {'id': 10173877527827, 'value': None}, {'id': 7819114194451, 'value': None}, {'id': 6216679695891, 'value': None}, {'id': 6301111953427, 'value': None}, {'id': 6301115951123, 'value': None}, {'id': 6022225997331, 'value': None}, {'id': 7942566588435, 'value': None}, {'id': 8536188728595, 'value': None}, {'id': 6301081613587, 'value': None}, {'id': 6875762866195, 'value': None}, {'id': 9525651192339, 'value': None}, {'id': 6301105142291, 'value': None}, {'id': 7942962756627, 'value': 'sub_trocas_e_devolucoes_sac_devolucao_de_produto_clonar'}, {'id': 10315707268627, 'value': None}, {'id': 9526180922131, 'value': None}, {'id': 7152916579347, 'value': None}, {'id': 9781833975059, 'value':  ...

# %%
import requests

credentials = "aW50ZWdyYWNhby56ZW5kZXNrQGNlbnRhdXJvLmNvbS5ici90b2tlbjp2U3FWTmtnRjU5bVN6dVc1YlQ3WmNJU1kwVFZxQmc0M3hBZGdHUGN4"
session = requests.Session()
session.auth = credentials
zendesk = 'https://atendimentocentauro.zendesk.com/'

topic_id = 123456
url = f'{zendesk}/api/v2/community/topics/{topic_id}/posts.json'
response = session.get(url)
if response.status_code != 200:
    print(f'Error with status code {response.status_code}')
    exit()
data = response.json()
topic_posts.extend(data['posts'])

for post in topic_posts:
    print(post['title'])

# %%
import json
import requests


# New ticket info
subject = 'My printer is on fire!'
body = 'The smoke is very colorful.'


# Package the data in a dictionary matching the expected JSON
data = {'ticket': {'subject': subject, 'comment': {'body': body}}}

# Encode the data to create a JSON payload
payload = json.dumps(data)

# Set the request parameters
url = 'https://limaconsulting9657.zendesk.com/api/v2/tickets.json'
user = 'esandro@limaconsulting.com'
pwd = '1049637227'
headers = {'content-type': 'application/json'}

# Do the HTTP post request
response = requests.post(url, data=payload, auth=(user, pwd), headers=headers)


# Check for HTTP codes other than 201 (Created)
if response.status_code != 201:
    print('Status:', response.status_code, 'Problem with the request. Exiting.')
    exit()

# Report success
print(response)
# Out:
# Status: 403 Problem with the request. Exiting.
# <Response [403]>

# %%
import json
import requests


# New ticket info
subject = 'My printer is on fire!'
body = 'The smoke is very colorful.'


# Package the data in a dictionary matching the expected JSON
data = {'ticket': {'subject': subject, 'comment': {'body': body}}}

# Encode the data to create a JSON payload
payload = json.dumps(data)

# Set the request parameters
url = 'https://limaconsulting9657.zendesk.com/api/v2/tickets/2.json'
user = 'esandro@limaconsulting.com'
pwd = '1049637227'
headers = {'content-type': 'application/json'}

# Do the HTTP post request
response = requests.get(url, data=payload, auth=(user, pwd), headers=headers)


# Check for HTTP codes other than 201 (Created)
if response.status_code != 201:
    print('Status:', response.status_code, 'Problem with the request. Exiting.')
    exit()

# Report success
print('Successfully created the ticket.')
# Out:
# Status: 200 Problem with the request. Exiting.
# Successfully created the ticket.

# %%
user = 'sustentacao@aktienow.com' + '/token'
pwd = '0zlfr6wxlGmbKCBp7nowSROMMGMqsJzw5k7YR5RV'

url = 'https://atendimentogruposbf.zendesk.com/'
endpoint = 'api/v2/tickets/recent'

# %%
creds = {
    'email' : 'sustentacao@aktienow.com',
    'token' : '0zlfr6wxlGmbKCBp7nowSROMMGMqsJzw5k7YR5RV',
    'subdomain': 'atendimentogruposbf'
}

# %%
from zenpy import Zenpy

# Default
zenpy_client = Zenpy(**creds)

# # Create a new ticket
# zenpy_client.tickets.create(Ticket(subject="Important", description="Thing"))

# # Perform a simple search
# for ticket in zenpy_client.search('PC LOAD LETTER', type='ticket', assignee='facetoe'):
#     # No need to mess around with ids, linked objects can be accessed directly.
#     print(ticket.requester.name)

#     # All objects can be converted to a Python dict.
#     print(ticket.to_dict())

#     # Or to JSON.
#     print(ticket.to_json())

# %%
zenpy_client.search(type='ticket', status='open')

# %%
for ticket in zenpy_client.search_export(type='ticket', status='open'):
    print(ticket.requester)
# Out:
# User(id=11080753900563)
# User(id=9872712248723)
# User(id=10362015163283)
# User(id=10299535602067)
# User(id=10935527877523)
# User(id=11037824046483)
# User(id=1912190001625)
# User(id=6683883309971)
# User(id=11062188661395)
# User(id=10478553661459)
# User(id=7304208309267)
# User(id=11045146453907)
# User(id=11047050278547)
# User(id=11080695678483)
# User(id=11080749416595)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:379, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378 try:  # Python 2.7, use buffering of HTTP responses
# --> 379     httplib_response = conn.getresponse(buffering=True)
#     380 except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py:277, in WrappedSocket.recv_into(self, *args, **kwargs)
#     276 try:
# --> 277     return self.connection.recv_into(*args, **kwargs)
#     278 except OpenSSL.SSL.SysCallError as e:
#
# File ~\anaconda3\lib\site-packages\OpenSSL\SSL.py:1800, in Connection.recv_into(self, buffer, nbytes, flags)
#    1799     result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1800 self._raise_ssl_error(self._ssl, result)
#    1802 # This strange line is all to avoid a memory copy. The buffer protocol
#    1803 # should allow us to assign a CFFI buffer to the LHS of this line, but
#    1804 # on CPython 3.3+ that segfaults. As a workaround, we can temporarily
#    1805 # wrap it in a memoryview.
#
# File ~\anaconda3\lib\site-packages\OpenSSL\SSL.py:1607, in Connection._raise_ssl_error(self, ssl, result)
#    1606 if error == _lib.SSL_ERROR_WANT_READ:
# -> 1607     raise WantReadError()
#    1608 elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 for ticket in zenpy_client.search_export(type='ticket', status='open'):
# ----> 2     print(ticket.requester)
#
# File ~\anaconda3\lib\site-packages\zenpy\lib\api_objects\__init__.py:4217, in Ticket.requester(self)
#    4213 """
#    4214 |  Comment: The user who requested this ticket
#    4215 """
#    4216 if self.api and self.requester_id:
# -> 4217     return self.api._get_user(self.requester_id)
#
# File ~\anaconda3\lib\site-packages\zenpy\lib\api.py:358, in Api._get_user(self, user_id)
#     356 if int(user_id) < 0:
#     357     return None
# --> 358 return self._query_zendesk(EndpointFactory('users'), 'user', id=user_id)
#
# File ~\anaconda3\lib\site-packages\zenpy\lib\api.py:266, in BaseApi._query_zendesk(self, endpoint, object_type, *endpoint_args, **endpoint_kwargs)
#     264         return item
#     265     else:
# --> 266         return self._get(url=self._build_url(
#     267             endpoint(*endpoint_args, **endpoint_kwargs)))
#     268 elif 'ids' in endpoint_kwargs:
#     269     cached_objects = []
#
# File ~\anaconda3\lib\site-packages\zenpy\lib\api.py:108, in BaseApi._get(self, url, raw_response, **kwargs)
#     107 def _get(self, url, raw_response=False, **kwargs):
# --> 108     response = self._call_api(self.session.get,
#     109                               url,
#     110                               timeout=self.timeout,
#     111                               **kwargs)
#     112     if raw_response:
#     113         return response
#
# File ~\anaconda3\lib\site-packages\zenpy\lib\api.py:135, in BaseApi._call_api(self, http_method, url, **kwargs)
#     131     response = self._ratelimit(http_method=http_method,
#     132                                url=url,
#     133                                **kwargs)
#     134 else:
# --> 135     response = http_method(url, **kwargs)
#     137 # If we are being rate-limited, wait the required period before trying again.
#     138 if response.status_code == 429:
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:535, in Session.get(self, url, **kwargs)
#     527 r"""Sends a GET request. Returns :class:`Response` object.
#     528
#     529 :param url: URL for the new :class:`Request` object.
#     530 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     531 :rtype: requests.Response
#     532 """
#     534 kwargs.setdefault('allow_redirects', True)
# --> 535 return self.request('GET', url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:522, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517 send_kwargs = {
#     518     'timeout': timeout,
#     519     'allow_redirects': allow_redirects,
#     520 }
#     521 send_kwargs.update(settings)
# --> 522 resp = self.send(prep, **send_kwargs)
#     524 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:642, in Session.send(self, request, **kwargs)
#     639 start = preferred_clock()
#     641 # Send the request
# --> 642 r = adapter.send(request, **kwargs)
#     644 # Total elapsed time of the request (approximately)
#     645 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:429, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     427 try:
#     428     if not chunked:
# --> 429         resp = conn.urlopen(
#     430             method=request.method,
#     431             url=url,
#     432             body=request.body,
#     433             headers=request.headers,
#     434             redirect=False,
#     435             assert_same_host=False,
#     436             preload_content=False,
#     437             decode_content=False,
#     438             retries=self.max_retries,
#     439             timeout=timeout
#     440         )
#     442     # Send the request.
#     443     else:
#     444         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594     self._prepare_proxy(conn)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#     606 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 except TypeError:  # Python 2.6 and older, Python 3
#     381     try:
# --> 382         httplib_response = conn.getresponse()
#     383     except Exception as e:
#     384         # Remove the TypeError from the exception chain in Python 3;
#     385         # otherwise it looks like a programming error was the cause.
#     386         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\contrib\pyopenssl.py:289, in WrappedSocket.recv_into(self, *args, **kwargs)
#     287         raise
#     288 except OpenSSL.SSL.WantReadError:
# --> 289     rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290     if not rd:
#     291         raise timeout('The read operation timed out')
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py:33, in wait_for_read(socks, timeout)
#      29 def wait_for_read(socks, timeout=None):
#      30     """ Waits for reading to be available from a list of sockets
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\util\wait.py:26, in _wait_for_io_events(socks, events, timeout)
#      23 for sock in socks:
#      24     selector.register(sock, events)
#      25 return [key[0].fileobj for key in
# ---> 26         selector.select(timeout) if key[1] & events]
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py:319, in SelectSelector.select(self, timeout)
#     317 timeout = None if timeout is None else max(timeout, 0.0)
#     318 ready = []
# --> 319 r, w, _ = _syscall_wrapper(self._select, True, self._readers,
#     320                            self._writers, timeout)
#     321 r = set(r)
#     322 w = set(w)
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py:64, in _syscall_wrapper(func, _, *args, **kwargs)
#      60 """ This is the short-circuit version of the below logic
#      61 because in Python 3.5+ all system calls automatically restart
#      62 and recalculate their timeouts. """
#      63 try:
# ---> 64     return func(*args, **kwargs)
#      65 except (OSError, IOError, select.error) as e:
#      66     errcode = None
#
# File ~\anaconda3\lib\site-packages\requests\packages\urllib3\util\selectors.py:310, in SelectSelector._select(self, r, w, timeout)
#     308 def _select(self, r, w, timeout=None):
#     309     """ Wrapper for select.select because timeout is a positional arg """
# --> 310     return select.select(r, w, [], timeout)
#
# KeyboardInterrupt:

# %%
import requests

url = 'https://api.gruposbf.com.br/crm-fisia/api/token'
user = "lima-dev"
pwd = "vsJtl4K4u2d1"
    


# Do the HTTP get request
response = requests.post(url, auth=(user, pwd))
print(response)
# Out:
# <Response [415]>

# %%
import requests

url = 'https://api.gruposbf.com.br/crm-fisia/api/token'
myobj = {"username": "lima-prd", "password": "9v770zk5Vkuf"}

x = requests.post(url, json = myobj)

print(x.text)
# Out:
# {"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6ImxpbWEtcHJkIiwibmJmIjoxNjY3NTY5MzAzLCJleHAiOjE2Njc2NTU3MDMsImlhdCI6MTY2NzU2OTMwM30.Nb6ePXYKNo2OH9pSFNhHZp5vb5T-c2JtWNKJvLcqxmA"}

# %%
    
url = 'https://api.gruposbf.com.br/crm-fisia/api/clientes/cpf=41028192827'
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6ImxpbWEtcHJkIiwibmJmIjoxNjY3NTY5MzAzLCJleHAiOjE2Njc2NTU3MDMsImlhdCI6MTY2NzU2OTMwM30.Nb6ePXYKNo2OH9pSFNhHZp5vb5T-c2JtWNKJvLcqxmA'
}

x = requests.get(url, headers=headers)

print(x.text)
# Out:
# [{"id":7026950,"codigo":"d40849fd-23c2-46c8-9a91-0717cc331e4b","tipoCliente":"PF","email":"41028192827@netshoes.com.br","endereco":{"local":"Padrão","logradouro":"Rua Arcoverde","numero":"3","complemento":"b","bairro":"Vila Guilhermina","referencia":null,"cep":"03543100","cidade":"São Paulo","uf":"SP","pais":"Brasil","telefone":{"ddd":"11","numero":"944745418"},"celular":{"ddd":"  ","numero":""},"nomeCompletoDeQuemIraRececeber":"Matheus Araujo","nomeDeQuemIraReceber":"Matheus","sobrenomeDeQuemIraReceber":"Araujo","email":"41028192827@netshoes.com.br"},"valesTrocaIds":[],"criadoEm":"2022-08-17T11:21:48.193","atualizadoEm":null,"possuiCompraRapidaHabilitada":false,"autenticado":true,"acessoBloqueado":false,"primeiroAcesso":false,"experienciaId":null,"timeCoracaoID":null,"timeDoCoracao":"","listaEsportesFavoritosSelecionados":null,"membroMove":false,"nome":"Matheus","sobrenome":"Araujo","sexo":"Não Aplicável","cpf":"41028192827","rg":"41028192827","dataNascimento":null,"mensagemErroValidacaoCadastro":null,"cnpj":null,"ie":null,"razaoSocial":null,"nomeFantasia":null,"cargo":null,"setor":null,"ramoDeAtividade":null,"newsletter":false,"origem":5,"urlOrigem":null}]

# %%
rows = x.text
#df = pd.json_normalize(rows)
print(x)
# Out:
# <Response [200]>
