# %%
from os import listdir
from os.path import isfile, join
from datetime import datetime
from time import sleep
import pandas as pd 
import json
import requests

# %%
url = "https://api.gruposbf.com.br/crm-fisia/api/token"

payload = json.dumps({
  "username": "lima-prd",
  "password": "9v770zk5Vkuf"
})

headers = {'Content-Type': 'application/json'}

response = requests.request("POST", url, headers=headers, data=payload, verify=False)
print(response.text)
# Out:
# {"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6ImxpbWEtcHJkIiwibmJmIjoxNjY4OTQ3NDk5LCJleHAiOjE2NjkwMzM4OTksImlhdCI6MTY2ODk0NzQ5OX0.SB35XGaYB7R_bpVO8JvGFXMMbWLe_8stqgGFwkfaWj8"}
# /home/erison/.local/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((

# %% [markdown]
# #### Parâmetros

# %%
token = 'Bearer ' + f'{response.text[10:-2]}'
path = "/home/erison/Desktop/lima/nike/projeto_crawler_zendesk_correios/downloads/netshoes/protocolos_tratados/"
agora = datetime.now()
data = agora.strftime('%d%m%Y')

# %% [markdown]
# #### Lendo os arquivos baixados do crawler

# %%
onlyfiles = [f for f in listdir(path)]

for ix in onlyfiles:
    if ix == f'dados_{data}.csv':
        df_protocolo = pd.read_csv(path+ix)
        #os.remove(path_download_protocolos+'\\'+ix)
        count = df_protocolo.shape[0]
        print(f'total registros: [{count}]')

# %%
#df_protocolo['cpf_cnpj'] = df_protocolo['cpf_cnpj'].drop_duplicates()

# %%
pd.set_option('display.max_columns', None)
df_protocolo.head()
# Out:
#   responsavel    pedido  protocolo    status             abertura  \
# 0     Lojista  98747872   64238491  PENDENTE  2022-11-18 23:48:14
# 1     Lojista  99045186   64238490  PENDENTE  2022-11-18 23:47:38
# 2     Lojista  98852089   64238485  PENDENTE  2022-11-18 23:45:20
# 3     Lojista  98536634   64238454  PENDENTE  2022-11-18 23:32:43
# 4     Lojista  99006994   64238433  PENDENTE  2022-11-18 23:24:00
#
#                     tipo_protocolo motivo_do_protocolo  \
# 0      Troca - Registro Automático              Troca
# 1  Devolução - Registro Automático           Devolução
# 2  Devolução - Registro Automático           Devolução
# 3  Devolução - Registro Automático           Devolução
# 4      Troca - Registro Automático              Troca
#
#                                  cliente      cpf_cnpj  \
# 0                          Matheus Bruno  5.220598e+09
# 1  Patricia  de Fatima Rodrigues Lamegal  2.481008e+10
# 2      Andreia Bandeira Januario Almeida  2.469574e+10
# 3           Daniel Bezerra Salomão Penha  1.010035e+10
# 4                            Cintia cruz  9.760594e+09
#
#   ultima_atualizacao_tramite tempo_em_aberto prioridade  \
# 0        2022-11-18 23:48:14             11h     Normal
# 1        2022-11-18 23:47:38             11h     Normal
# 2        2022-11-18 23:45:20             11h     Normal
# 3        2022-11-18 23:32:43             12h     Normal
# 4        2022-11-18 23:24:00             12h     Normal
#
#                                                 chat  cpf_crawler  \
# 0  18 de Novembro de 2022\n- 23:48\nProcesso de T...   5220598139
# 1  18 de Novembro de 2022\n- 23:47\nProcesso de T...  24810079805
# 2  18 de Novembro de 2022\n- 23:45\nProcesso de T...  24695737850
# 3  18 de Novembro de 2022\n- 23:32\nProcesso de T...  10100354602
# 4  18 de Novembro de 2022\n- 23:24\nProcesso de T...   9760593718
#
#                cod_sku       Data da Compra  Valor Total Pedido Lojista  \
# 0  ['2IC-8138-014-40']  12/11/2022 12:09:54                      475.99
# 1  ['2IC-9527-030-03']  17/11/2022 01:07:23                      299.99
# 2  ['2IC-8026-026-41']  14/11/2022 10:18:22                      339.99
# 3  ['JD8-0084-008-03']  09/11/2022 22:09:07                       59.49
# 4  ['2IC-8576-014-05']  16/11/2022 15:33:39                       93.99
#
#                                      Nome do Produto  Valor sku  Qtd sku  \
# 0                    Tênis Nike Air Max SC Masculino     475.99        1
# 1  Camisa Nike Brasil I 2022/23 Torcedor Pro Infa...     299.99        1
# 2                    Tênis Nike SB Chron 2 Masculino     339.99        1
# 3              Shorts Nike Dri-FIT Academy Masculino      59.49        1
# 4                            Camiseta Nike Masculina      93.99        1
#
#       SKU MktPlace  codigo_item       CEP                        Endereço  \
# 0  2IC-8138-014-40  583494463.0  72035503                    Quadra CSG 3
# 1  2IC-9527-030-03  584163085.0   3283000                      Rua Uhland
# 2  2IC-8026-026-41  583723492.0   6852430                Rua Buenos Aires
# 3  JD8-0084-008-03  583083446.0  37542000  Avenida  PREFEITO GABRIEL ROSA
# 4  2IC-8576-014-05  584073835.0  22753005            Estrada do Itanhanga
#
#    Número               Complemento                       Bairro Estado  \
# 0     609  Tagua life - Apto  609 d  Taguatinga Sul (Taguatinga)     DF
# 1    1122                         0                     Vila Ema     SP
# 2     897                         0               Parque Paraíso     SP
# 3     217           BANCO DO BRASIL                       CENTRO     MG
# 4    2898                         0                    Itanhangá     RJ
#
#                  Cidade
# 0              BRASILIA
# 1             São Paulo
# 2  ITAPECERICA DA SERRA
# 3                ESTIVA
# 4        RIO DE JANEIRO

# %% [markdown]
# #### Fazendo a chamada na API NIKE

# %%
cpf = []
index = 0
total_df = df_protocolo['cpf_cnpj'].shape[0]
for c in df_protocolo['cpf_cnpj']:
    a = len(str(c))
    if a < 11:
        cpf.append(str(c).zfill(11))
    else:
        cpf.append(c)
    index += 1

print(f'total cpf df: {index}')
print(f'total cpf: {total_df}')



dado_api = []

for i in cpf:
#    sleep(1.5)
    url = f'https://api.gruposbf.com.br/crm-fisia/api/clientes/cpf={i}'
    headers = {'Authorization' : token}
    x = requests.request("GET", url, headers=headers, verify=False)
    
    t = json.loads(x.text)
    dados_api.append(t) 

#     conn = http.client.HTTPSConnection("api.gruposbf.com.br")
#     payload = ''
#     headers = {
#       'Content-Type': 'application/json',
#       'Authorization': token
#     }
#     conn.request("GET", f"/crm-fisia/api/clientes/cpf={i}", payload, headers)
#     res = conn.getresponse()
#     data = res.read()

    
#     print(data.decode("utf-8"))
#     t = json.loads(data.decode("utf-8"))
#     dado_api.append(t)
# Out:
# total cpf df: 291
# total cpf: 291
# /home/erison/.local/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [28], in <cell line: 23>()
#      26 headers = {'Authorization' : token}
#      27 x = requests.request("GET", url, headers=headers, verify=False)
# ---> 29 t = json.loads(x.text)
#      30 dados_api.append(t)
#
# File /usr/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File /usr/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
dado_api
# Out:
# ['Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados',
#  'Nao foi possivel obter os dados']

# %%
dados = pd.Series(dado_api).to_frame(name='dados')
dados = dados.explode(column='dados', ignore_index=True)
df = pd.json_normalize(data=dados['dados'])

# %%
df = df.rename(columns={'endereco.local': 'local', 
                        'endereco.logradouro': 'logradouro',       
                        'endereco.numero': 'numero', 
                        'endereco.complemento': 'complemento', 
                        'endereco.bairro': 'bairro',
                        'endereco.referencia': 'referencia', 
                        'endereco.cep': 'cep',
                        'endereco.cidade': 'cidade',
                        'endereco.uf': 'uf',
                        'endereco.pais': 'pais', 
                        'endereco.telefone.ddd': 'telefone_ddd', 
                        'endereco.telefone.numero': 'telefone_numero',      
                        'endereco.celular.ddd': 'celular_ddd', 
                        'endereco.celular.numero': 'celular_numero',
                        
})
df['nome_completo'] = df['nome'] +' '+ df['sobrenome']
df_api = df.loc[:, ['id', 
                  'tipoCliente', 
                  'email',
                  'nome_completo',  
                  'sexo', 
                  'cpf', 
                  'rg', 
                  'dataNascimento',   
                  'cnpj', 
                  'local', 
                  'logradouro',       
                  'numero', 
                  'complemento', 
                  'bairro',
                  'referencia', 
                  'cep',
                  'cidade',
                  'uf',
                  'pais', 
                  'telefone_ddd', 
                  'telefone_numero',      
                  'celular_ddd', 
                  'celular_numero'
    ]]

# %%
df[df_api['cpf'] == '10041275969']

# %%
df_protocolo.head()

# cpf = []
# index = 0
# total_df = df_protocolo['cpf_cnpj'].shape[0]
# for c in df_protocolo['cpf_cnpj']:
#     a = len(str(c))
#     if a < 11:
#         cpf.append(str(c).zfill(11))
#     else:
#         cpf.append(str(c))
#     index += 1

# print(f'total cpf df: {index}')
# print(f'total cpf: {total_df}')

# %%
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

#df[df_api['cpf'] == '01144187133']

#df_api['cpf'] = df_api['cpf'].drop_duplicates()
#df_api['cpf'].value_counts()
#df_api
df_protocolo['cpf']

# %%
df_protocolo = df_protocolo.rename(columns={'cpf_cnpj':'cpf'})
df_protocolo['cpf'] = df_protocolo['cpf'].astype(str)


#df = df_protocolo.merge(df_teste,  on=['cpf'], how='left')

# %%
df_api
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_api
#
# NameError: name 'df_api' is not defined

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
onlyfiles = [f for f in listdir(path_download_protocolos)]
print(onlyfiles)

for ix in onlyfiles:
    df_atendimento = pd.read_excel(path_download_protocolos+ix, engine="openpyxl", usecols="A:K", )
    os.remove(path_download_protocolos+'\\'+ix)
    print('leu')

# %% [markdown]
# ## API CORREIOS

# %%
# -*- coding: utf-8 -*-

from unittest import TestCase
from correios_lib.webservices import LogisticaReversa
from correios_lib.entities import Remetente, Destinatario, Coleta, \
     Objeto, Produto, ColetaSimultanea
from correios_lib.requests import RequestSolicitarPostagemReversa, \
     RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
     RequestCancelarPedido, RequestSolicitarRange, \
     RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
import datetime

# %%
cliente=LogisticaReversa(
    env='PROD',
    id_correios='grupo.sbf',
    password='centauro2021',
    cert=True)

# %%
for i, row in df1.iterrows():
    print(row)
    
    pedido = row['pedido']
    etiqueta_postagem = 'Numero Da etiqueta'
    descricao_produto = row['Nome do Produto']
    quantidade = row['Qtd sku']
    valor = row['Valor sku']
    cliente = row['cliente']
    status = row['status']
    subject = 'Solicitação de troca devolução - Protocolo Portal'

    
    request = RequestSolicitarPostagemReversa(
                codAdministrativo='13415611',
                codigo_servico='04677',
                cartao='0075199017',

                destinatario=Destinatario(
                    nome='Nike - JP LOGISTICA',
                    logradouro='Rodovia Fernão Dias',
                    numero='S/N',
                    complemento='Km 947.5 G40 Modulo B-NIVEL1',
                    bairro='Bairro dos Pires',
                    cidade='́Extrema',
                    uf='MG',
                    cep='37640950'
                ),

                coletas_solicitadas=[
                    Coleta(
                        tipo='A',
                        valor_declarado=1500.00,
                        remetente=Remetente(
                            nome='Ciclano',
                            logradouro='Rua 35',
                            numero='10',
                            bairro='Águas Claras(Sul)',
                            cidade='Brasília',
                            uf='DF',
                            cep='71931-180',
                            ddd='61',
                            telefone='34262222',
                            email='ciclano@mail.com',
                            identificacao='',
                            ddd_celular='61',
                            celular='92236666',
                            sms='N'
                        ),

#                         obj_col=[
#                             Objeto(
#                                 item=1,
#                                 id='582298235'

#                             )
#                         ]
#                     )
#                 ]
#             )

# response = cliente.SolicitarPostagemReversa(request)
#    print(requests)
