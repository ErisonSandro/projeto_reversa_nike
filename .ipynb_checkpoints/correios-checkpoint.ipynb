# %%
#https://github.com/trocafone/correios-lib/blob/master/tests/integration/webservices/logistica_reversa_test.py

from unittest import TestCase
from correios_lib.webservices import LogisticaReversa
from correios_lib.entities import Remetente, Destinatario, Coleta, \
     Objeto, Produto, ColetaSimultanea
from correios_lib.requests import RequestSolicitarPostagemReversa, \
     RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
     RequestCancelarPedido, RequestSolicitarRange, \
     RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
import datetime



# def test_get_env(self):
#         self.assertEquals(
#             'https://apphom.correios.com.br/logisticaReversaWS/'
#             'logisticaReversaService/logisticaReversaWS?wsdl',
#             self.client.get_env('HOMOLOG')
#         )
#         self.assertEquals(
#             'https://cws.correios.com.br/logisticaReversaWS/'
#             'logisticaReversaService/logisticaReversaWS?wsdl',
#             self.client.get_env('PROD')
#         )


#cliente=LogisticaReversa(
#    env='PROD',
#    id_correios='grupo.sbf',
#    password='centauro2021',
#    cert=True)


client = LogisticaReversa(
            env='HOMOLOG',
            id_correios='empresacws',
            password='123456',
            cert=True
        )

#codAdministrativo='13415611',
#codigo_servico='04677',
#cartao='0075199017',
#id_cliente='grupo.sbf',


request = RequestSolicitarPostagemReversa(
            codAdministrativo='',
            codigo_servico='',
            cartao='',
            destinatario=Destinatario(
                nome='',
                logradouro='',
                numero='',
                complemento='',
                bairro='',
                cidade='́',
                uf='',
                cep='',
                ddd='',
                telefone='',
                email=''
            ),
            coletas_solicitadas=[
                Coleta(
                    tipo='C',
                    id_cliente='',
                    valor_declarado=,
                    cklist=,
                    documento=[],
                    remetente=Remetente(
                        nome='',
                        logradouro='',
                        numero='',
                        bairro='',
                        cidade='',
                        uf='',
                        cep='',
                        ddd='',
                        telefone='',
                        email='',
                        identificacao='',
                        ddd_celular='',
                        celular='',
                        sms=''
                    ),
                    produto=Produto(
                        codigo='116600063',
                        tipo='0',
                        qtd='1'
                    ),
                    ag=5,
                    obj_col=[
                        Objeto(
                            item=1,
                            id='553366'
                        )
                    ]
                )
            ]
        )

response = client.SolicitarPostagemReversa(request)

print(response)
# Out:
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:28, in parse_xml(content, transport, parser_context, base_url)
#      27 try:
# ---> 28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
#
# File ~\anaconda3\lib\site-packages\defusedxml\lxml.py:143, in fromstring(text, parser, base_url, forbid_dtd, forbid_entities)
#     142     parser = getDefaultParser()
# --> 143 rootelement = _etree.fromstring(text, parser, base_url=base_url)
#     144 elementtree = rootelement.getroottree()
#
# File src/lxml/etree.pyx:3252, in lxml.etree.fromstring()
#
# File src/lxml/parser.pxi:1913, in lxml.etree._parseMemoryDocument()
#
# File src/lxml/parser.pxi:1800, in lxml.etree._parseDoc()
#
# File src/lxml/parser.pxi:1141, in lxml.etree._BaseParser._parseDoc()
#
# File src/lxml/parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src/lxml/parser.pxi:654, in lxml.etree._raiseParseError()
#
# XMLSyntaxError: Extra content at the end of the document, line 520, column 3 (<string>, line 520)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 35>()
#      11 import datetime
#      15 # def test_get_env(self):
#      16 #         self.assertEquals(
#      17 #             'https://apphom.correios.com.br/logisticaReversaWS/'
#    (...)
#      31 #    password='centauro2021',
#      32 #    cert=True)
# ---> 35 client = LogisticaReversa(
#      36             env='HOMOLOG',
#      37             id_correios='empresacws',
#      38             password='123456',
#      39             cert=True
#      40         )
#      42 #codAdministrativo='13415611',
#      43 #codigo_servico='04677',
#      44 #cartao='0075199017',
#      45 #id_cliente='grupo.sbf',
#      48 request=RequestSolicitarPostagemReversa(
#      49             codAdministrativo='08082650',
#      50             codigo_servico='04677',
#    (...)
#     101             ]
#     102         )
#
# File ~\anaconda3\lib\site-packages\correios_lib\base.py:96, in WebserviceBase.__init__(self, env, id_correios, password, cert, log_config)
#      90     logging.config.dictConfig(log_config)
#      92 t = Transport(
#      93     verify=verify,
#      94     http_auth=(id_correios, password)
#      95 )
# ---> 96 self.client = Client(wsdl=self.get_env(env), transport=t)
#
# File ~\anaconda3\lib\site-packages\zeep\client.py:52, in Client.__init__(self, wsdl, wsse, transport, service_name, port_name)
#      49     raise ValueError("No URL given for the wsdl")
#      51 self.transport = transport or Transport()
# ---> 52 self.wsdl = Document(wsdl, self.transport)
#      53 self.wsse = wsse
#      55 self._default_service = None
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:61, in Document.__init__(self, location, transport)
#      57 self._parser_context = ParserContext()
#      59 document = self._load_content(location)
# ---> 61 root_definitions = Definition(self, document, self.location)
#      62 root_definitions.resolve_imports()
#      64 # Make the wsdl definitions public
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:146, in Definition.__init__(self, wsdl, doc, location)
#     143 # Process the definitions
#     144 self.parse_imports(doc)
# --> 146 self.types = self.parse_types(doc)
#     147 self.messages = self.parse_messages(doc)
#     148 self.port_types = self.parse_ports(doc)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:280, in Definition.parse_types(self, doc)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
# --> 280 schema_nodes = [
#     281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:281, in <listcomp>(.0)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
#     280 schema_nodes = [
# --> 281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:30, in parse_xml(content, transport, parser_context, base_url)
#      28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
# ---> 30     raise XMLSyntaxError("Invalid XML content received (%s)" % exc.message)
#
# AttributeError: 'XMLSyntaxError' object has no attribute 'message'

# %%
###############################################################################################################
from unittest import TestCase
from correios_lib.webservices import LogisticaReversa
from correios_lib.entities import Remetente, Destinatario, Coleta, \
     Objeto, Produto, ColetaSimultanea
from correios_lib.requests import RequestSolicitarPostagemReversa, \
     RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
     RequestCancelarPedido, RequestSolicitarRange, \
     RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
import datetime


cliente=LogisticaReversa(
    env='PROD',
    id_correios='grupo.sbf',
    password='centauro2021',
    cert=True)



# request = RequestSolicitarPostagemReversa(
#             codAdministrativo='13415611',
#             codigo_servico='04677',
#             cartao='0075199017',
            
#             destinatario=Destinatario(
#                 nome='Fisia Comércio de Produtos Esportivos Ltda',
#                 logradouro='Rodovia Fernão Dias',
#                 numero='S/N',
#                 complemento='Km 947.5 - Galpão Modulo 3640',
#                 cidade='́Extrema',
#                 uf='MG',
#                 cep='37640-903',
#             ),
    
#             coletas_solicitadas=[
#                 Coleta(
#                     tipo='A',
                    
#                     remetente=Remetente(
#                         nome='pedro junior',
#                         logradouro='Estrada do Gama',
#                         numero='1580',
#                         complemento = 'Cond Teotônio Vilela bl18ap304',
#                        # bairro='',
#                         cidade='MACEIO',
#                         uf='AL',
#                         cep='57046295',
#                         ddd='82',
#                         telefone='996594776',
#                         email='teste@teste.com',
#                         identificacao='6780631418',
#                         ddd_celular='',
#                         celular='',

#                     )
#                 )
#             ]
#         )


# request = RequestAcompanharPedidoPorData(
#     codAdministrativo='13415611',
#     tipoSolicitacao='A',
#     data=datetime.date(2022, 10, 24)
# )
# response = cliente.RequestAcompanharPedidoPorData()

# print(response)



request = RequestAcompanharPedido(
        codAdministrativo='13415611',
        tipoBusca='H',
        tipoSolicitacao='A',
        numeroPedido= 94925797
    )
response = cliente.AcompanharPedido(request)

print(response)
# Out:
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:28, in parse_xml(content, transport, parser_context, base_url)
#      27 try:
# ---> 28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
#
# File ~\anaconda3\lib\site-packages\defusedxml\lxml.py:143, in fromstring(text, parser, base_url, forbid_dtd, forbid_entities)
#     142     parser = getDefaultParser()
# --> 143 rootelement = _etree.fromstring(text, parser, base_url=base_url)
#     144 elementtree = rootelement.getroottree()
#
# File src/lxml/etree.pyx:3252, in lxml.etree.fromstring()
#
# File src/lxml/parser.pxi:1913, in lxml.etree._parseMemoryDocument()
#
# File src/lxml/parser.pxi:1800, in lxml.etree._parseDoc()
#
# File src/lxml/parser.pxi:1141, in lxml.etree._BaseParser._parseDoc()
#
# File src/lxml/parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src/lxml/parser.pxi:654, in lxml.etree._raiseParseError()
#
# XMLSyntaxError: Extra content at the end of the document, line 520, column 3 (<string>, line 520)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 13>()
#       6 from correios_lib.requests import RequestSolicitarPostagemReversa, \
#       7      RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
#       8      RequestCancelarPedido, RequestSolicitarRange, \
#       9      RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
#      10 import datetime
# ---> 13 cliente=LogisticaReversa(
#      14     env='PROD',
#      15     id_correios='grupo.sbf',
#      16     password='centauro2021',
#      17     cert=True)
#      21 # request = RequestSolicitarPostagemReversa(
#      22 #             codAdministrativo='13415611',
#      23 #             codigo_servico='04677',
#    (...)
#      68
#      69 # print(response)
#      73 request = RequestAcompanharPedido(
#      74         codAdministrativo='13415611',
#      75         tipoBusca='H',
#      76         tipoSolicitacao='A',
#      77         numeroPedido= 94925797
#      78     )
#
# File ~\anaconda3\lib\site-packages\correios_lib\base.py:96, in WebserviceBase.__init__(self, env, id_correios, password, cert, log_config)
#      90     logging.config.dictConfig(log_config)
#      92 t = Transport(
#      93     verify=verify,
#      94     http_auth=(id_correios, password)
#      95 )
# ---> 96 self.client = Client(wsdl=self.get_env(env), transport=t)
#
# File ~\anaconda3\lib\site-packages\zeep\client.py:52, in Client.__init__(self, wsdl, wsse, transport, service_name, port_name)
#      49     raise ValueError("No URL given for the wsdl")
#      51 self.transport = transport or Transport()
# ---> 52 self.wsdl = Document(wsdl, self.transport)
#      53 self.wsse = wsse
#      55 self._default_service = None
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:61, in Document.__init__(self, location, transport)
#      57 self._parser_context = ParserContext()
#      59 document = self._load_content(location)
# ---> 61 root_definitions = Definition(self, document, self.location)
#      62 root_definitions.resolve_imports()
#      64 # Make the wsdl definitions public
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:146, in Definition.__init__(self, wsdl, doc, location)
#     143 # Process the definitions
#     144 self.parse_imports(doc)
# --> 146 self.types = self.parse_types(doc)
#     147 self.messages = self.parse_messages(doc)
#     148 self.port_types = self.parse_ports(doc)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:280, in Definition.parse_types(self, doc)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
# --> 280 schema_nodes = [
#     281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:281, in <listcomp>(.0)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
#     280 schema_nodes = [
# --> 281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:30, in parse_xml(content, transport, parser_context, base_url)
#      28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
# ---> 30     raise XMLSyntaxError("Invalid XML content received (%s)" % exc.message)
#
# AttributeError: 'XMLSyntaxError' object has no attribute 'message'

# %%
from correios_lib.base import WebserviceBase

env='HOMOLOG'
id_correios='empresacws'
password='123456'
cert=False

class LogisticaReversa(WebserviceBase):


    
    def get_env(self, env):
        envs = {
            'HOMOLOG': 'https://apphom.correios.com.br/logisticaReversaWS/'
                       'logisticaReversaService/logisticaReversaWS?wsdl',
            'PROD': 'https://cws.correios.com.br/logisticaReversaWS/'
                    'logisticaReversaService/logisticaReversaWS?wsdl',
        }

        return envs[env]

    def SolicitarPostagemReversa(self, request):
        return self.call("solicitarPostagemReversa", request)
    

a = LogisticaReversa(env, id_correios, password)
print(a.SolicitarPostagemReversa())
# Out:
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:28, in parse_xml(content, transport, parser_context, base_url)
#      27 try:
# ---> 28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
#
# File ~\anaconda3\lib\site-packages\defusedxml\lxml.py:143, in fromstring(text, parser, base_url, forbid_dtd, forbid_entities)
#     142     parser = getDefaultParser()
# --> 143 rootelement = _etree.fromstring(text, parser, base_url=base_url)
#     144 elementtree = rootelement.getroottree()
#
# File src/lxml/etree.pyx:3252, in lxml.etree.fromstring()
#
# File src/lxml/parser.pxi:1913, in lxml.etree._parseMemoryDocument()
#
# File src/lxml/parser.pxi:1800, in lxml.etree._parseDoc()
#
# File src/lxml/parser.pxi:1141, in lxml.etree._BaseParser._parseDoc()
#
# File src/lxml/parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src/lxml/parser.pxi:654, in lxml.etree._raiseParseError()
#
# XMLSyntaxError: Extra content at the end of the document, line 520, column 3 (<string>, line 520)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 26>()
#      22     def SolicitarPostagemReversa(self, request):
#      23         return self.call("solicitarPostagemReversa", request)
# ---> 26 a = LogisticaReversa(env, id_correios, password)
#      27 print(a.SolicitarPostagemReversa())
#
# File ~\anaconda3\lib\site-packages\correios_lib\base.py:96, in WebserviceBase.__init__(self, env, id_correios, password, cert, log_config)
#      90     logging.config.dictConfig(log_config)
#      92 t = Transport(
#      93     verify=verify,
#      94     http_auth=(id_correios, password)
#      95 )
# ---> 96 self.client = Client(wsdl=self.get_env(env), transport=t)
#
# File ~\anaconda3\lib\site-packages\zeep\client.py:52, in Client.__init__(self, wsdl, wsse, transport, service_name, port_name)
#      49     raise ValueError("No URL given for the wsdl")
#      51 self.transport = transport or Transport()
# ---> 52 self.wsdl = Document(wsdl, self.transport)
#      53 self.wsse = wsse
#      55 self._default_service = None
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:61, in Document.__init__(self, location, transport)
#      57 self._parser_context = ParserContext()
#      59 document = self._load_content(location)
# ---> 61 root_definitions = Definition(self, document, self.location)
#      62 root_definitions.resolve_imports()
#      64 # Make the wsdl definitions public
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:146, in Definition.__init__(self, wsdl, doc, location)
#     143 # Process the definitions
#     144 self.parse_imports(doc)
# --> 146 self.types = self.parse_types(doc)
#     147 self.messages = self.parse_messages(doc)
#     148 self.port_types = self.parse_ports(doc)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:280, in Definition.parse_types(self, doc)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
# --> 280 schema_nodes = [
#     281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:281, in <listcomp>(.0)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
#     280 schema_nodes = [
# --> 281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:30, in parse_xml(content, transport, parser_context, base_url)
#      28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
# ---> 30     raise XMLSyntaxError("Invalid XML content received (%s)" % exc.message)
#
# AttributeError: 'XMLSyntaxError' object has no attribute 'message'

# %%
# !pip show correios-lib
# Out:
# Name: correios-lib
# Version: 0.1.0
# Summary: Interface python com logs para uso dos serviços fornecidos pelo SIGEPWeb dos Correios.
# Home-page: https://github.com/trocafone/correios-lib
# Author: Flávio Briz
# Author-email: flavio.briz@gmail.com
# License: MIT License
# Location: c:\users\erisonsandro\anaconda3\lib\site-packages
# Requires: certifi, voluptuous, zeep, brazilnum
# Required-by:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\erisonsandro\anaconda3\lib\site-packages)

# %%
from unittest import TestCase
from correios_lib.webservices import LogisticaReversa
from correios_lib.entities import Remetente, Destinatario, Coleta, \
     Objeto, Produto, ColetaSimultanea
from correios_lib.requests import RequestSolicitarPostagemReversa, \
     RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
     RequestCancelarPedido, RequestSolicitarRange, \
     RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 from unittest import TestCase
# ----> 2 from correios_lib.webservices import LogisticaReversa
#       3 from correios_lib.entities import Remetente, Destinatario, Coleta, \
#       4      Objeto, Produto, ColetaSimultanea
#       5 from correios_lib.requests import RequestSolicitarPostagemReversa, \
#       6      RequestAcompanharPedido, RequestAcompanharPedidoPorData, \
#       7      RequestCancelarPedido, RequestSolicitarRange, \
#       8      RequestCalcularDigitoVerificador, RequestSolicitarPostagemSimultanea
#
# ModuleNotFoundError: No module named 'correios_lib'

# %%
cliente=LogisticaReversa(
    env='PROD',
    id_correios='grupo.sbf',
    password='centauro2021',
    cert=True)


request = RequestAcompanharPedidoPorData(
    codAdministrativo='13415611',
    tipoSolicitacao='A',
    data=datetime.date(2022, 10, 24)
)
response = cliente.AcompanharPedidoPorData(request)


print(response)
# Out:
# ---------------------------------------------------------------------------
# XMLSyntaxError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:28, in parse_xml(content, transport, parser_context, base_url)
#      27 try:
# ---> 28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
#
# File ~\anaconda3\lib\site-packages\defusedxml\lxml.py:143, in fromstring(text, parser, base_url, forbid_dtd, forbid_entities)
#     142     parser = getDefaultParser()
# --> 143 rootelement = _etree.fromstring(text, parser, base_url=base_url)
#     144 elementtree = rootelement.getroottree()
#
# File src/lxml/etree.pyx:3252, in lxml.etree.fromstring()
#
# File src/lxml/parser.pxi:1913, in lxml.etree._parseMemoryDocument()
#
# File src/lxml/parser.pxi:1800, in lxml.etree._parseDoc()
#
# File src/lxml/parser.pxi:1141, in lxml.etree._BaseParser._parseDoc()
#
# File src/lxml/parser.pxi:615, in lxml.etree._ParserContext._handleParseResultDoc()
#
# File src/lxml/parser.pxi:725, in lxml.etree._handleParseResult()
#
# File src/lxml/parser.pxi:654, in lxml.etree._raiseParseError()
#
# XMLSyntaxError: Extra content at the end of the document, line 520, column 3 (<string>, line 520)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 cliente=LogisticaReversa(
#       2     env='PROD',
#       3     id_correios='grupo.sbf',
#       4     password='centauro2021',
#       5     cert=True)
#       8 request = RequestAcompanharPedidoPorData(
#       9     codAdministrativo='13415611',
#      10     tipoSolicitacao='A',
#      11     data=datetime.date(2022, 10, 24)
#      12 )
#      13 response = cliente.AcompanharPedidoPorData(request)
#
# File ~\anaconda3\lib\site-packages\correios_lib\base.py:96, in WebserviceBase.__init__(self, env, id_correios, password, cert, log_config)
#      90     logging.config.dictConfig(log_config)
#      92 t = Transport(
#      93     verify=verify,
#      94     http_auth=(id_correios, password)
#      95 )
# ---> 96 self.client = Client(wsdl=self.get_env(env), transport=t)
#
# File ~\anaconda3\lib\site-packages\zeep\client.py:52, in Client.__init__(self, wsdl, wsse, transport, service_name, port_name)
#      49     raise ValueError("No URL given for the wsdl")
#      51 self.transport = transport or Transport()
# ---> 52 self.wsdl = Document(wsdl, self.transport)
#      53 self.wsse = wsse
#      55 self._default_service = None
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:61, in Document.__init__(self, location, transport)
#      57 self._parser_context = ParserContext()
#      59 document = self._load_content(location)
# ---> 61 root_definitions = Definition(self, document, self.location)
#      62 root_definitions.resolve_imports()
#      64 # Make the wsdl definitions public
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:146, in Definition.__init__(self, wsdl, doc, location)
#     143 # Process the definitions
#     144 self.parse_imports(doc)
# --> 146 self.types = self.parse_types(doc)
#     147 self.messages = self.parse_messages(doc)
#     148 self.port_types = self.parse_ports(doc)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:280, in Definition.parse_types(self, doc)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
# --> 280 schema_nodes = [
#     281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\wsdl\wsdl.py:281, in <listcomp>(.0)
#     275     return Schema(
#     276         None, self.wsdl.transport, self.location,
#     277         self.wsdl._parser_context)
#     279 # FIXME: This fixes `test_parse_types_nsmap_issues`, lame solution...
#     280 schema_nodes = [
# --> 281     xsd_parse_xml(etree.tostring(schema_node), self.location)
#     282     for schema_node in schema_nodes
#     283 ]
#     285 if len(schema_nodes) == 1:
#     286     return Schema(
#     287         schema_nodes[0], self.wsdl.transport, self.location,
#     288         self.wsdl._parser_context)
#
# File ~\anaconda3\lib\site-packages\zeep\xsd\parser.py:30, in parse_xml(content, transport, parser_context, base_url)
#      28     return fromstring(content, parser=parser, base_url=base_url)
#      29 except etree.XMLSyntaxError as exc:
# ---> 30     raise XMLSyntaxError("Invalid XML content received (%s)" % exc.message)
#
# AttributeError: 'XMLSyntaxError' object has no attribute 'message'
